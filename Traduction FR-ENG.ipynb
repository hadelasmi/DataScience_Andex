# %%
from googletrans import Translator

# %%
translator = Translator()

# %%
L = translator.translate('Vos missions consisteront à développer et faire évoluer des modèles sur des champs aussi larges que le marketing (modèles d’attrition, détection des moments de vie ou d’événements bancaires, le risque (scores d’octroi, modèle de pré évaluation, les processus (octroi, distribution, la tarification, l’appui à la distribution (marketing opérationnel ou relationnel) ou la réglementation. ')
print(L)
# Out:
# Your missions will consist of developing and evolving models in fields as broad as marketing (attrition models, detection of life moments or banking events, risk (grant scores, pre-evaluation model, processes (granting, distribution, pricing, distribution support (operational or relationship marketing) or regulations.

# %%
from translate import Translator

# %%
translator= Translator(from_lang='fr',to_lang='en')
translation = translator.translate("Vos missions consisteront à développer et faire évoluer des modèles sur des champs aussi larges que le marketing (modèles d’attrition, détection des moments de vie ou d’événements bancaires, le risque (scores d’octroi, modèle de pré évaluation, les processus (octroi, distribution, la tarification, l’appui à la distribution (marketing opérationnel ou relationnel) ou la réglementation. Modéliser, diffuser, enrichir et faire évoluer les modèles (score d’attrition, d’octroi, segmentation, moments de vie en s’appuyant notamment sur des nouveaux types de données (données de  ")
print(translation)
# Out:
# QUERY LENGTH LIMIT EXCEDEED. MAX ALLOWED QUERY : 500 CHARS

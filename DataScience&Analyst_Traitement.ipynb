# %%
import numpy as np
import pandas as pd
import nltk
import re
import os
import codecs

# %%
dfs = pd.read_excel("C:/Users/lenovo/Desktop/Andex/Phase de construction des PILIERS/Data_Analyst_Scientist_TEST1/Fiches_Data_Analyst_Scientist.xlsx")
print(dfs)
# Out:
#             Id                                         Titre  \
# 0      BNP_268         data scientist deep learning images
# 1       BNP_52             data scientist project assistant
# 2       BNP_86     data scientist intelligence artificielle
# 3     BPCE_127             data scientist strategie data ia
# 4      BPCE_32                               data scientist
# 5       CA_113                          market data analyst
# 6       CA_237                         datascientist ia nlp
# 7       CM_174                data analyst service financier
# 8        CM_81              data scientist traitement images
# 9       LCL_62                                  data analyst
# 10      LCL_65                                data scientist
# 11  SOCGEN_107        data analyst charge etudes financieres
# 12  SOCGEN_135              data scientist embargo sanctions
# 13  SOCGEN_156  datascientist statisticien marketing risque
#
# ...

# %%
descriptions = dfs['descriptif']

# %%
print(descriptions)
# Out:
# 0     Stage – Data Scientist – Deep learning on imag...
# 1     ALTERNANCE - DATA SCIENTIST – PROJECT ASSISTAN...
# 2     SENIOR DATA SCIENTIST - INTELLIGENCE ARTIFICIE...
# 3     Le Groupe BPCE, deuxième groupe bancaire en Fr...
# 4     Natixis Assurances conçoit et gère une offre c...
# 5     Types de métiers Crédit Agricole S.A. - Analys...
# 6     Types de métiers Crédit Agricole S.A. - Systèm...
# 7     Au sein du middle office de la Direction des I...
# 8     L’expertise technologique au service de la cli...
# 9     Crédit Agricole Leasing Factoring est un acteu...
# 10    Crédit Agricole Leasing Factoring est un acteu...
# 11    Vos missions au quotidien\nLa banque de détail...
# 12    Responsibilities\nSous la responsabilité de vo...
# 13    Vos missions au quotidien\nAu cours des projet...
# Name: descriptif, dtype: object

# %%
def tokenize_only(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word.lower() for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    return filtered_tokens

# %%
totalvocab_tokenized = []
for i in descriptions:
    allwords_tokenized = tokenize_only(i)
    totalvocab_tokenized.extend(allwords_tokenized)

# %%
vocab_frame = pd.DataFrame({'words': totalvocab_tokenized})

# %%
print(vocab_frame.count())
print(type(vocab_frame))
# Out:
# words    7761
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>

# %%
print(type(totalvocab_tokenized))
# Out:
# <class 'list'>

# %%
totalvocab_tokenized.replace('',"")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-4b57b50f28a7> in <module>
# ----> 1 totalvocab_tokenized.replace('',"")
#
# AttributeError: 'list' object has no attribute 'replace'

# %%
vocab_frame = pd.DataFrame({'words': totalvocab_tokenized})

# %%
print(vocab_frame.count())
# Out:
# words    7759
# dtype: int64

# %%
totalvocab_tokenized.read()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-be2b310293f9> in <module>
# ----> 1 totalvocab_tokenized.read()
#
# AttributeError: 'list' object has no attribute 'read'

# %%
import nltk
from nltk.corpus import stopwords
set(stopwords.words('french'))
# Out:
# {'ai',
#  'aie',
#  'aient',
#  'aies',
#  'ait',
#  'as',
#  'au',
#  'aura',
#  'aurai',
#  'auraient',
#  'aurais',
#  'aurait',
#  'auras',
#  'aurez',
#  'auriez',
#  'aurions',
#  'aurons',
#  'auront',
#  'aux',
#  'avaient',
#  'avais',
#  'avait',
#  'avec',
#  'avez',
#  'aviez',
#  'avions',
#  'avons',
#  'ayant',
#  'ayante',
#  'ayantes',
#  'ayants',
#  'ayez',
#  'ayons',
#  'c',
#  'ce',
#  'ces',
#  'd',
#  'dans',
#  'de',
#  'des',
#  'du',
#  'elle',
#  'en',
#  'es',
#  'est',
#  'et',
#  'eu',
#  'eue',
#  'eues',
#  'eurent',
#  'eus',
#  'eusse',
#  'eussent',
#  'eusses',
#  'eussiez',
#  'eussions',
#  'eut',
#  'eux',
#  'eûmes',
#  'eût',
#  'eûtes',
#  'furent',
#  'fus',
#  'fusse',
#  'fussent',
#  'fusses',
#  'fussiez',
#  'fussions',
#  'fut',
#  'fûmes',
#  'fût',
#  'fûtes',
#  'il',
#  'ils',
#  'j',
#  'je',
#  'l',
#  'la',
#  'le',
#  'les',
#  'leur',
#  'lui',
#  'm',
#  'ma',
#  'mais',
#  'me',
#  'mes',
#  'moi',
#  'mon',
#  'même',
# ...

# %%
import nltk
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
from stop_words import get_stop_words
stop_words = get_stop_words('english')
#word_tokenize accepts a string as an input, not a file. 
file1 = open("C:/Users/lenovo/Desktop/vocabu.txt", encoding='utf8')
line = file1.read()# Use this to read file content as a stream: 
#print(line)
gui1 = "'"
gui2 = "'"
words = line.split()

for w in words:
    w.replace(gui1,"").replace(gui2,"")
    #rint(w)
print(words)
for r in words: 
    if not r in stop_words: 
        appendFile = open('V1.txt','a') 
        appendFile.write(" "+r) 
        appendFile.close()
# Out:
# ["['stage',", "'data',", "'scientist',", "'deep',", "'learning',", "'on',", "'images',", "'of',", "'documents',", "'concrètement',", "'votre',", "'quotidien',", "'vous',", "'intégrerez',", "'équipe',", "'du',", "'datalab',", "'au',", "'sein',", "'du',", "'département',", "'corporate',", "'data',", "'amp',", "'analytics',", "'qui',", "'a',", "'pour',", "'mission',", "'de',", "'promouvoir',", "'la',", "'valorisation',", "'des',", "'données',", "'au',", "'sein',", "'de',", "'bnp',", "'paribas',", "'cardif',", "'via',", "'la',", "'mise',", "'en',", "'place',", "'de',", "'projets',", "'fortes',", "'composantes',", "'analytics',", "'data',", "'science',", "'et',", "'intelligence',", "'artificielle',", "'machine',", "'learning',", "'deep',", "'learning',", "'dataviz',", "'la',", "'formalisation',", "'et',", "'le',", "'partage',", "'des',", "'best-practices',", "'la',", "'veille',", "'active',", "'et',", "'la',", "'r',", "'amp',", "'d.',", "'vous',", "'rejoindrez',", "'plus',", "'précisément
# ...

# %%
stop_words = stopwords.words('french')

# %%
[word for word in words if word not in stop_words]
# Out:
# ["'stage',",
#  "'data',",
#  "'scientist',",
#  "'deep',",
#  "'learning',",
#  "'on',",
#  "'images',",
#  "'of',",
#  "'documents',",
#  "'concrètement',",
#  "'votre',",
#  "'quotidien',",
#  "'vous',",
#  "'intégrerez',",
#  "'équipe',",
#  "'du',",
#  "'datalab',",
#  "'au',",
#  "'sein',",
#  "'du',",
#  "'département',",
#  "'corporate',",
#  "'data',",
#  "'amp',",
#  "'analytics',",
#  "'qui',",
#  "'a',",
#  "'pour',",
#  "'mission',",
#  "'de',",
#  "'promouvoir',",
#  "'la',",
#  "'valorisation',",
#  "'des',",
#  "'données',",
#  "'au',",
#  "'sein',",
#  "'de',",
#  "'bnp',",
#  "'paribas',",
#  "'cardif',",
#  "'via',",
#  "'la',",
#  "'mise',",
#  "'en',",
#  "'place',",
#  "'de',",
#  "'projets',",
#  "'fortes',",
#  "'composantes',",
#  "'analytics',",
#  "'data',",
#  "'science',",
#  "'et',",
#  "'intelligence',",
#  "'artificielle',",
#  "'machine',",
#  "'learning',",
#  "'deep',",
#  "'learning',",
#  "'dataviz',",
#  "'la',",
#  "'formalisation',",
# ...

# %%
print(file1)
# Out:
# <_io.TextIOWrapper name='C:/Users/lenovo/Desktop/vocabu.txt' mode='r' encoding='utf8'>

# %%
import nltk
from nltk.corpus import stopwords
set(stopwords.words('english'))
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
# ...

# %%
import io 
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
#word_tokenize accepts a string as an input, not a file. 
stop_words = set(stopwords.words('english')) 
print(stop_words)
file1 = open("C:/Users/lenovo/Desktop/vocabu.txt", encoding='utf8')
line = file1.read()# Use this to read file content as a stream: 
words = line.split(", ") 
for r in words: 
    print(r)
    if not r in stop_words: 
        appendFile = open('AMAN3.txt','a') 
        appendFile.write(" "+r) 
        appendFile.close()
# Out:
# {'yourself', 'under', 'couldn', 'they', 'was', 'ourselves', 'does', 'themselves', "you've", "should've", 'mustn', 'both', 'some', 'now', 'above', 'too', "wouldn't", 'through', 't', "aren't", "shouldn't", "haven't", 'same', 'to', 'were', 'been', 'on', 'didn', 'are', 'a', 'doesn', "you'd", "needn't", "shan't", 'most', 'down', 'up', 'ours', 'she', 'what', 'whom', "you're", 'few', 'shan', 'he', 'out', 'mightn', 'of', 'our', 'i', 'that', 'myself', "weren't", "won't", 'during', 'shouldn', 'between', 'if', 'doing', 'o', 'had', 'again', 'once', 'because', 'nor', 'wasn', 'while', 'those', 'll', 'hers', 'but', 'you', 'don', 'more', 'theirs', 'am', 'by', 'hasn', 'why', 'haven', 'my', "you'll", 'or', 'her', 'with', 'them', 'ma', "mustn't", 'until', 'this', 'which', 'be', 'there', "that'll", 'so', 'needn', 'where', 'should', 'other', 'then', 'from', 'further', 'no', 'these', "couldn't", "it's", 'when', 'very', 'is', 'm', 'd', 'how', "hasn't", 'in', 'weren', 'before', 'won', 'such', 'yourselves', 
# ...

# %%
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ...

# %% [markdown]
# ## file1 = open("C:/Users/lenovo/Desktop/vocabu.txt", encoding='utf8')
# line = file1.read()# Use this to read file content as a stream:
# #print(line)
# print(type(line))
# words = line.split(" ")
# print((words))

# %%
import nltk
stopwords = nltk.corpus.stopwords.words('french')
print(stopwords)
# Out:
# ['au', 'aux', 'avec', 'ce', 'ces', 'dans', 'de', 'des', 'du', 'elle', 'en', 'et', 'eux', 'il', 'ils', 'je', 'la', 'le', 'les', 'leur', 'lui', 'ma', 'mais', 'me', 'même', 'mes', 'moi', 'mon', 'ne', 'nos', 'notre', 'nous', 'on', 'ou', 'par', 'pas', 'pour', 'qu', 'que', 'qui', 'sa', 'se', 'ses', 'son', 'sur', 'ta', 'te', 'tes', 'toi', 'ton', 'tu', 'un', 'une', 'vos', 'votre', 'vous', 'c', 'd', 'j', 'l', 'à', 'm', 'n', 's', 't', 'y', 'été', 'étée', 'étées', 'étés', 'étant', 'étante', 'étants', 'étantes', 'suis', 'es', 'est', 'sommes', 'êtes', 'sont', 'serai', 'seras', 'sera', 'serons', 'serez', 'seront', 'serais', 'serait', 'serions', 'seriez', 'seraient', 'étais', 'était', 'étions', 'étiez', 'étaient', 'fus', 'fut', 'fûmes', 'fûtes', 'furent', 'sois', 'soit', 'soyons', 'soyez', 'soient', 'fusse', 'fusses', 'fût', 'fussions', 'fussiez', 'fussent', 'ayant', 'ayante', 'ayantes', 'ayants', 'eu', 'eue', 'eues', 'eus', 'ai', 'as', 'avons', 'avez', 'ont', 'aurai', 'auras', 'aura', 'aurons', 'a
# ...

# %%
def remove_stopwords(line):
    txt_clean = [word for word in line if word not in stopwords]
    return txt_clean

# %%
line.apply(remove_stopwords())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-145-55a78fe8b285> in <module>
# ----> 1 line.apply(remove_stopwords())
#
# AttributeError: 'str' object has no attribute 'apply'

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
#word_tokenize accepts a string as an input, not a file. 
stop_words = set(stopwords.words("english")) 

with open("C:/Users/lenovo/Desktop/data.txt",'r', encoding='utf8') as f2:
    data = f2.read()
v1 = data.split(sep=', ')

filtered_sentence =[]
for w in v1:
    if w not in stop_words:
        filtered_sentence.append(w)
print(filtered_sentence)
# Out:
# ['stage', 'data', 'scientist', 'deep', 'learning', 'images', 'documents', 'concrètement', 'quotidien', 'intégrerez', 'équipe', 'datalab', 'sein', 'département', 'corporate', 'data', 'amp', 'analytics', 'mission', 'promouvoir', 'valorisation', 'données', 'sein', 'bnp', 'paribas', 'cardif', 'via', 'mise', 'place', 'projets', 'fortes', 'composantes', 'analytics', 'data', 'science', 'intelligence', 'artificielle', 'machine', 'learning', 'deep', 'learning', 'dataviz', 'formalisation', 'partage', 'best-practices', 'veille', 'active', 'r', 'amp', 'rejoindrez', 'plus', 'précisément', 'équipe', 'document', 'image', 'processing', 'datalab', 'cette', 'équipe', 'développe', 'service', 'combinant', 'optical', 'character', 'recognition', 'classification', 'extraction', 'information', 'qualifiée', 'automatiser', 'traitement', 'dizaines', 'millions', 'documents', 'reçus', 'bnp', 'paribas', 'cardif', 'chaque', 'année', 'sujet', 'stage', 'concerne', 'plus', 'précisément', 'amélioration', 'classificati
# ...

# %%
import nltk
from nltk.tokenize import word_tokenize 
from nltk.tokenize import sent_tokenize
import re

with open("C:/Users/lenovo/Desktop/data_jdida.txt",'r', encoding='utf8') as f2:
    data = f2.read()
    #print(data)
    #print(type(data))
res = data.split(', ') 

#print(res)
val = (re.split('[-,+#]', data))
#print((val))
rea = data.replace(',',' ')
print(rea)
T=['' for j in range (len(res)//3)]
k=0
for i in range (len(res)-2):
    if i % 3 == 0 :
        T[k] = res[i]+" "+res[i+1]+" "+res[i+2]
        k=k+1
print(T)
#print(word_tokenize(rea))
# Out:
# 19ème  partenariats  contexte  rejoignant  différents  grand  situation  aude  appétence  mettrez  recueil  vérifiées  mesure  audit  suivi  études  précision  distribués  ingénierie  hardware  experts  pays  informatique  expérience  librairies  tensorflow  contacté  évoluer  euros  gestion  job  complexité  initiatives  aspect  projet  universitaire  docker  approches  livrables  office  durée  base  particulière  art  recherchées  profil  établirez  bien  bon  prérequis  offre  postulez  reconnaître  quotidien  gpus  recrutons  crédit-bail  communautaire  créant  analytiques  leviers  regardless  managers  haut  animation  political  data-centric  populaires  départements  ciblages  soulevées  titre  travaillerez  forte  characteristic  cas  souhaité  intégration  défenseur  monde  soucieux  tient  cpsi  calf  langages  r  douvrage  flex  scientifique.la  créé   minimum  quantité  intéraction  evaluer  recommendation  dordres  .net  saisie  rémunération  sujet  validation  interac
# ...

# %%
def tokenize_only(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word.lower() for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    return filtered_tokens

# %%
totalvocab_tokenized = []
for i in v1:
    allwords_tokenized = tokenize_only(i)
    totalvocab_tokenized.extend(allwords_tokenized)

# %%
print(totalvocab_tokenized)
# Out:
# ["'stage", 'data', 'scientist', "'deep", "'learning", "'images", "'documents", "'concrètement", "'quotidien", "'intégrerez", "'équipe", "'datalab", "'sein", "'département", "'corporate", "'data", "'amp", "'analytics", "'mission", "'promouvoir", "'valorisation", "'données", "'sein", "'bnp", "'paribas", "'cardif", "'via", "'mise", "'place", "'projets", "'fortes", "'composantes", "'analytics", "'data", "'science", "'intelligence", "'artificielle", "'machine", "'learning", "'deep", "'learning", "'dataviz", "'formalisation", "'partage", "'best-practices", "'veille", "'active", 'r', "'amp", "'rejoindrez", "'précisément", "'équipe", "'document", "'image", "'processing", "'datalab", "'cette", "'équipe", "'développe", "'service", "'combinant", "'optical", "'character", "'recognition", "'classification", "'extraction", "'information", "'qualifiée", "'automatiser", "'traitement", "'dizaines", "'millions", "'documents", "'reçus", "'bnp", "'paribas", "'cardif", "'chaque", "'année", "'sujet", "'st
# ...

# %%
mots = "A B C D E F"

for i in range(0,len(mots)):
    print(mots[i])
# Out:
# A
#
# B
#
# C
#
# D
#
# E
#
# F
